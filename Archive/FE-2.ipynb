# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# Objective:
# - Check the prediction result and find the factors that might cause prediction error
# - Create features which can resolve error factors

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
DATA_PATH = "./data"

# %%
import os

os.listdir(DATA_PATH)
# Out:
# ['bert_result',
#  'data_eval_labels.csv',
#  'data_eval_tfidf.csv',
#  'data_eval_word2vec.csv',
#  'data_josa_removed.csv',
#  'data_preprocessed.csv',
#  'data_train_labels.csv',
#  'hidden_for_inference.csv',
#  'list_josa.txt',
#  'list_tags_candidates.txt',
#  'sample',
#  '몽데이크_Open.csv',
#  '중단원_summary.csv']

# %%
df_train_label = pd.read_csv(DATA_PATH+'/data_train_labels.csv')
df_train_label.head()
# Out:
#    chapter bert_80_pred_chapter tfidf_pred_chapter  \
# 0  H1S1-08              H1S1-08            H1S1-08
# 1  H1S1-08              H1S1-08            H1S1-08
# 2  H1S1-11              H1S1-11            H1S1-11
# 3  H1S1-07              H1S1-07            H1S1-07
# 4  H1S1-12              H1S1-12            H1S1-01
#
#                word2vec_pred_chapter  \
# 0  ['H1S1-08', 'H1S1-08', 'H1S1-08']
# 1  ['H1S1-08', 'HSU1-06', 'H1S1-08']
# 2  ['H1S1-11', 'H1S1-12', 'H1S1-11']
# 3  ['H1S1-07', 'H1S1-10', 'H1S1-08']
# 4  ['H1S1-12', 'H1S1-06', 'H1S2-03']
#
#                                                 text        qtid  \
# 0  연립부등식 `{(-x-3 >= -2x+1), (2x+a <= 10) :}`의 해가 ...  H1S1-08-05
# 1                        부등식 `[x]^2-2[x]-3 < 0`의 해는?  H1S1-08-11
# 2  점 `(1, 2)`를 지나며 중심이 직선 `x-y-1=0` 위에 있고 `x`축에 접...  H1S1-11-05
# 3  `x`, `y`가 정수일 때, 방정식 `xy+2x-3y=7`을 만족하는 순서쌍 `(...  H1S1-07-18
# 4  평행이동 `(x, y)->(x+2, y-7)`에 의해 포물선 `y=x^2`을 평행이...  H1S1-12-03
#
#                        name  \
# 0      해를 갖거나 갖지 않는 연립일차부등식
# 1  절댓값 또는 가우스 기호가 포함된 이차부등식
# 2      x축 또는 y축에 접하는 원의 방정식
# 3     정수 및 자연수 조건을 갖는 부정방정식
# 4              도형의 평행이동 (2)
#
#                                   word2vec_pred_name  qplay_question_id
# 0  ['연립이차부등식', '정수인 해의 개수가 주어진 연립부등식', '해를 갖거나 갖지...               3504
# 1  ['이차부등식', '삼각부등식 (2)', '절댓값 또는 가우스 기호가 포함된 이차부...               3675
# 2  ['x축 또는 y축에 접하는 원의 방정식', '평행이동과 대칭이동의 활용', 'x축...               3779
# 3  ['정수 및 자연수 조건을 갖는 부정방정식', '평행한 두 직선 사이의 거리', '...               3649
# 4  ['도형의 평행이동 (2)', '식의 최댓값과 최솟값 (2)', '코시-슈바르츠의 ...               3388

# %%
token = pd.read_csv(DATA_PATH+'/data_josa_removed.csv')['text']
math_hangul = pd.read_csv(DATA_PATH+'/data_preprocessed.csv')[['math_field', 'hangul_field']]
display(token.head(2))
display(math_hangul.head(2))
# Out:
# 0    ['연립부등식', '`', '{', '(', '-', 'x', '-3', '>', ...
# 1    ['부등식', '`', '[', 'x', ']', '^', '2', '-2', '[...
# Name: text, dtype: object
#                                    math_field  \
# 0  ['{(-x-3 >= -2x+1), (2x+a <= 10) :}', 'a']
# 1                        ['[x]^2-2[x]-3 < 0']
#
#                                 hangul_field
# 0  ['연립부등식', '해', '존재하도록', '하', '최댓값', '구하']
# 1                               ['부등식', '해']

# %%
df_train_label['token'] = token
df_train_label[['math_field', 'hangul_field']] = math_hangul
df_train_label.head()
# Out:
#    chapter bert_80_pred_chapter tfidf_pred_chapter  \
# 0  H1S1-08              H1S1-08            H1S1-08
# 1  H1S1-08              H1S1-08            H1S1-08
# 2  H1S1-11              H1S1-11            H1S1-11
# 3  H1S1-07              H1S1-07            H1S1-07
# 4  H1S1-12              H1S1-12            H1S1-01
#
#                word2vec_pred_chapter  \
# 0  ['H1S1-08', 'H1S1-08', 'H1S1-08']
# 1  ['H1S1-08', 'HSU1-06', 'H1S1-08']
# 2  ['H1S1-11', 'H1S1-12', 'H1S1-11']
# 3  ['H1S1-07', 'H1S1-10', 'H1S1-08']
# 4  ['H1S1-12', 'H1S1-06', 'H1S2-03']
#
#                                                 text        qtid  \
# 0  연립부등식 `{(-x-3 >= -2x+1), (2x+a <= 10) :}`의 해가 ...  H1S1-08-05
# 1                        부등식 `[x]^2-2[x]-3 < 0`의 해는?  H1S1-08-11
# 2  점 `(1, 2)`를 지나며 중심이 직선 `x-y-1=0` 위에 있고 `x`축에 접...  H1S1-11-05
# 3  `x`, `y`가 정수일 때, 방정식 `xy+2x-3y=7`을 만족하는 순서쌍 `(...  H1S1-07-18
# 4  평행이동 `(x, y)->(x+2, y-7)`에 의해 포물선 `y=x^2`을 평행이...  H1S1-12-03
#
#                        name  \
# 0      해를 갖거나 갖지 않는 연립일차부등식
# 1  절댓값 또는 가우스 기호가 포함된 이차부등식
# 2      x축 또는 y축에 접하는 원의 방정식
# 3     정수 및 자연수 조건을 갖는 부정방정식
# 4              도형의 평행이동 (2)
#
#                                   word2vec_pred_name  qplay_question_id  \
# 0  ['연립이차부등식', '정수인 해의 개수가 주어진 연립부등식', '해를 갖거나 갖지...               3504
# 1  ['이차부등식', '삼각부등식 (2)', '절댓값 또는 가우스 기호가 포함된 이차부...               3675
# 2  ['x축 또는 y축에 접하는 원의 방정식', '평행이동과 대칭이동의 활용', 'x축...               3779
# 3  ['정수 및 자연수 조건을 갖는 부정방정식', '평행한 두 직선 사이의 거리', '...               3649
# 4  ['도형의 평행이동 (2)', '식의 최댓값과 최솟값 (2)', '코시-슈바르츠의 ...               3388
#
#                                                token  \
# 0  ['연립부등식', '`', '{', '(', '-', 'x', '-3', '>', ...
# 1  ['부등식', '`', '[', 'x', ']', '^', '2', '-2', '[...
# 2  ['점', '`', '(', '1', ',', '2', ')', '`', '지나',...
# 3  ['`', 'x', '`,', '`', 'y', '`', '정수일', '때', ',...
# 4  ['평행이동', '`', '(', 'x', ',', 'y', ')', '->', '...
#
#                                           math_field  \
# 0         ['{(-x-3 >= -2x+1), (2x+a <= 10) :}', 'a']
# 1                               ['[x]^2-2[x]-3 < 0']
# 2                         ['(1, 2)', 'x-y-1=0', 'x']
# 3                 ['x', 'y', 'xy+2x-3y=7', '(x, y)']
# 4  ['(x, y)->(x+2, y-7)', 'y=x^2', 'y=x^2+px+q', ...
#
#                                         hangul_field
# 0          ['연립부등식', '해', '존재하도록', '하', '최댓값', '구하']
# 1                                       ['부등식', '해']
# 2  ['점', '지나', '중심', '직선', '위', '있', '축', '접하', '...
# 3            ['정수일', '때', '방정식', '만족하', '순서쌍', '개수']
# 4  ['평행이동', '의해', '포물선', '평행이동하였더', '포물선', '되었다',...

# %%
wrong_list = []
for i in df.index:
    if df.loc[i, 'chapter'] not in df.loc[i, 'word2vec_pred_chapter']:
        wrong_list.append(i)
        
wrong_df = df.loc[wrong_list]
wrong_df.reset_index(inplace=True)
wrong_df.head(2)
# Out:
#    index  chapter        qtid  \
# 0      7  H1S1-03  H1S1-03-08
# 1     27  H1S1-05  H1S1-05-12
#
#                                                 text  \
# 0  다항식 `3x^2+kx+7`이 모든 계수가 정수인 두 일차식의 곱으로 인수분해될 때...
# 1  `x`에 대한 이차식 `x^2+2x+4`를 복소수의 범위에서 인수분해하였을 때, 인...
#
#                                math_field  \
# 0                      ['3x^2+kx+7', 'k']
# 1  ['x', 'x^2+2x+4', 'A', 'B', '(A-B)^2']
#
#                                         hangul_field tag_field  \
# 0  ['다항식', '모든', '계수', '정수', '두', '일차식', '곱', '인수...        []
# 1  ['대', '이차식', '복소수', '범위', '인수분해하였', '때', '인수',...        []
#
#               name subtitle  qplay_question_id  question_difficulty  \
# 0  조건이 주어진 식의 인수분해      NaN               4002                    4
# 1  이차식의 복소수범위 인수분해      NaN               3866                    3
#
#    question_type_difficulty  grade purpose              word2vec_pred_chapter  \
# 0                       3.0     10    open  ['HSU1-09', 'H1S1-08', 'H1S1-07']
# 1                       2.0     10    open  ['H1S1-01', 'H1S1-11', 'H1S1-11']
#
#                              word2vec_pred_name  \
# 0  ['등비수열의 활용', '이차방정식의 근의 위치', '삼차방정식의 근의 판별']
# 1       ['다항식의 덧셈과 뺄셈', '접선의 길이', '원의 방정식 (2)']
#
#                                                token
# 0  ['다항식', '`', '3', 'x', '^', '2', '+', 'kx', '+...
# 1  ['`', 'x', '`', '대', '이차식', '`', 'x', '^', '2'...

# %% [markdown]
# ---
# wrong_df는 제 word2vec 모델로 중단원을 예측 하였을 때 전혀 맞추지 못한 문제들의 리스트입니다.
# 이 worng 데이터를 쭉 살펴보시고 공통점은 무엇인지, 왜 잘못 판단 하였는지 정성적으로 분석해보시면 좋을 것 같습니다.
# 모든 데이터를 다 보실 필요는 없고 (너무 힘들겁니다 ㅠ) 쭉 보시며 중요하다 생각되는 부분 위주로 분석해주세요!
#
# 또한 오류를 유발한 factor를 어떻게 제거할 수 있을지도 고민해주시면 좋을 것 같습니다.
# (잘못 판단한 이유로는 토큰화가 잘못되었다던가, 문제에 정보가 부족하다던가, 기호가 잘못 판단되었다던가 하는 문제가 있을 것 같습니다.)
# (참고로 word2vec 모델을 사용할 때에는 name과 token이외에 아무것도 사용하지 않았습니다. 이 두 칼럼 안에 답이 있을 것 같습니다.)
# ---

# %% [markdown]
# ### Example)

# %%
wrong_df.loc[0, 'text']
# Out:
# '다항식 `3x^2+kx+7`이 모든 계수가 정수인 두 일차식의 곱으로 인수분해될 때, 상수 `k`가 가질 수 있는 값 중 최솟값을 구하시오.]'

# %%
wrong_df.loc[0, 'token']
# Out:
# "['다항식', '`', '3', 'x', '^', '2', '+', 'kx', '+', '7', '`', '모든', '계수', '정수', '두', '일차식', '곱', '인수분해될', '때', ',', '상수', '`', 'k', '`', '가질', '수', '있', '값', '중', '최솟값', '구하시오', '.', ']']"

# %%
wrong_df.loc[0, 'name']
# Out:
# '조건이 주어진 식의 인수분해'

# %%
wrong_df.loc[0, 'word2vec_pred_name']
# Out:
# "['등비수열의 활용', '이차방정식의 근의 위치', '삼차방정식의 근의 판별']"

# %% [markdown]
# '인수분해' 라는 단어가 문제에 있음에도 불구하고 엉뚱하게 예측한 것은,
# '인수분해'가 '인수분해될' 로 token화 되어 제대로 인식되지 않은 탓인 것 같습니다.
# '될' 까지 조사로 처리하여 제거할 필요가 있을 것 같습니다.

# %% [markdown]
# ## word2vec 모델로 예측하지 못한 경우

# %%
wrong_list_word2vec = np.zeros(len(df_train_label), dtype=int)

for i in df_train_label.index:
    if df_train_label.loc[i, 'chapter'] not in df_train_label.loc[i, 'word2vec_pred_chapter']:
        wrong_list_word2vec[i] = 1
        
df_train_label['wrong_word2vec'] = wrong_list_word2vec
print("word2vec이 예측하지 못한 문제 개수: {}/{}".format(sum(wrong_list_word2vec), df_train_label.shape[0]))
df_train_label[df_train_label['wrong_word2vec']==1].head()
# Out:
# word2vec이 예측하지 못한 문제 개수: 974/5364
#     chapter bert_80_pred_chapter tfidf_pred_chapter  \
# 7   H1S1-03              H1S1-03            H1S1-03
# 27  H1S1-05              H1S1-05            H1S1-05
# 28  H1S1-05              H1S1-05            H1S1-05
# 30  H1S1-10              H1S1-10            H1S1-10
# 31  H1S1-12              H1S1-12            H1S1-12
#
#                 word2vec_pred_chapter  \
# 7   ['HSU1-09', 'H1S1-08', 'H1S1-07']
# 27  ['H1S1-01', 'H1S1-11', 'H1S1-11']
# 28  ['HSU1-03', 'H1S1-11', 'H1S1-08']
# 30  ['H1S1-11', 'H1S1-11', 'H1S1-12']
# 31  ['H1S1-03', 'H1S2-05', 'H1S2-05']
#
#                                                  text        qtid  \
# 7   다항식 `3x^2+kx+7`이 모든 계수가 정수인 두 일차식의 곱으로 인수분해될 때...  H1S1-03-08
# 27  `x`에 대한 이차식 `x^2+2x+4`를 복소수의 범위에서 인수분해하였을 때, 인...  H1S1-05-12
# 28  이차식 `kx^2+4x+k`가 `x`에 대한 완전제곱식이 되기 위한 실수 `k`의 ...  H1S1-05-07
# 30           점 `(2, 1)`을 지나고 기울기가 `3`인 직선의 방정식을 구하시오?  H1S1-10-01
# 31  원 `(x-2)^2+(y-3)^2=1`을 점 `M(-1, 1)`에 대하여 대칭이동하...  H1S1-12-09
#
#                  name                                 word2vec_pred_name  \
# 7     조건이 주어진 식의 인수분해       ['등비수열의 활용', '이차방정식의 근의 위치', '삼차방정식의 근의 판별']
# 27    이차식의 복소수범위 인수분해            ['다항식의 덧셈과 뺄셈', '접선의 길이', '원의 방정식 (2)']
# 28  이차식이 완전제곱식이 되는 조건  ['근의 조건이 주어진 지수방정식', '방정식이 원을 나타내기 위한 조건', '이차...
# 30        직선의 방정식 (1)  ['x축 또는 y축에 접하는 원의 방정식', '원의 방정식 (1)', '점의 평행이동']
# 31         점에 대한 대칭이동          ['치환을 이용한 인수분해', '유리식과 항등식', '유리식의 사칙연산']
#
#     qplay_question_id                                              token  \
# 7                4002  ['다항식', '`', '3', 'x', '^', '2', '+', 'kx', '+...
# 27               3866  ['`', 'x', '`', '대', '이차식', '`', 'x', '^', '2'...
# 28               3965  ['이차식', '`', 'kx', '^', '2', '+', '4', 'x', '+...
# 30               4425  ['점', '`', '(', '2', ',', '1', ')', '`', '지나',...
# 31               4601  ['원', '`', '(', 'x', '-2', ')', '^', '2', '+',...
#
#                                            math_field  \
# 7                                  ['3x^2+kx+7', 'k']
# 27             ['x', 'x^2+2x+4', 'A', 'B', '(A-B)^2']
# 28                            ['kx^2+4x+k', 'x', 'k']
# 30                                    ['(2, 1)', '3']
# 31  ['(x-2)^2+(y-3)^2=1', 'M(-1, 1)', '(x-a)^2+(y-...
#
#                                          hangul_field  wrong_word2vec  \
# 7   ['다항식', '모든', '계수', '정수', '두', '일차식', '곱', '인수...               1
# 27  ['대', '이차식', '복소수', '범위', '인수분해하였', '때', '인수',...               1
# 28   ['이차식', '대', '완전제곱식', '되기', '위', '실수', '값', '합']               1
# 30            ['점', '지나', '기울기', '직선', '방정식', '구하시오']               1
# 31              ['원', '점', '대하', '대칭이동하', '옮겨진', '값']               1
#
#     wrong_tfidf
# 7             0
# 27            0
# 28            0
# 30            0
# 31            0

# %% [markdown]
# ## tf-idf 모델로 예측하지 못한 경우

# %%
wrong_list_tdidf = np.zeros(len(df_train_label), dtype=int)

for i in df_train_label.index:
    if df_train_label.loc[i, 'chapter'] != df_train_label.loc[i, 'tfidf_pred_chapter']:
        wrong_list_tdidf[i] = 1
        
df_train_label['wrong_tfidf'] = wrong_list_tdidf
print("tf-idf가 예측하지 못한 문제 개수: {}/{}".format(sum(wrong_list_tdidf), df_train_label.shape[0]))
df_train_label[df_train_label['wrong_tfidf']==1].head()
# Out:
# tf-idf가 예측하지 못한 문제 개수: 613/5364
#     chapter bert_80_pred_chapter tfidf_pred_chapter  \
# 4   H1S1-12              H1S1-12            H1S1-01
# 15  H1S1-01              H1S1-01            H1S1-02
# 17  H1S1-03              H1S1-03            H1S1-01
# 20  H1S1-10              H1S1-10            H1S1-01
# 23  H1S1-09              H1S1-09            H1S1-01
#
#                 word2vec_pred_chapter  \
# 4   ['H1S1-12', 'H1S1-06', 'H1S2-03']
# 15  ['H1S1-01', 'H1S1-03', 'H1S1-02']
# 17  ['H1S2-05', 'HSU1-01', 'H1S1-03']
# 20  ['H1S1-10', 'H1S1-10', 'H1S1-10']
# 23  ['H1S1-09', 'H1S1-10', 'H1S1-10']
#
#                                                  text        qtid  \
# 4   평행이동 `(x, y)->(x+2, y-7)`에 의해 포물선 `y=x^2`을 평행이...  H1S1-12-03
# 15  오른쪽 조립제법은 `ax^2+bx+c`를 `(x-p)`로 나눈 몫을 다시 `(x+q...  H1S1-01-09
# 17                   `(2060^3-1)/(2061xx2060+1)`의 값은?  H1S1-03-11
# 20  좌표평면 위의 세 점 `O(0, 0)`, `A(2, 3)`, `B(-3, 5)`를 ...  H1S1-10-15
# 23  좌표평면 위의 두 점 `A(1, 1)`, `B(3, -2)`와 `y`축 위를 움직이...  H1S1-09-05
#
#              name                                 word2vec_pred_name  \
# 4    도형의 평행이동 (2)  ['도형의 평행이동 (2)', '식의 최댓값과 최솟값 (2)', '코시-슈바르츠의 ...
# 15           조립제법              ['조립제법', '치환을 이용한 인수분해', '조립제법과 항등식']
# 17   인수분해의 활용 (3)            ['부분분수로의 변형', '지수의 확장', '인수분해의 활용 (3)']
# 20        삼각형의 수심  ['삼각형의 수심', '선분을 수직이등분하는 방정식', '세 점이 한 직선 위에 있...
# 23  두 점 사이 거리의 활용  ['같은 거리에 있는 점', '도형의 넓이를 절반으로 나누는 직선의 방정식', '자...
#
#     qplay_question_id                                              token  \
# 4                3388  ['평행이동', '`', '(', 'x', ',', 'y', ')', '->', '...
# 15               4046  ['오른쪽', '조립제법', '`', 'ax', '^', '2', '+', 'bx'...
# 17               4383  ['`', '(', '2060', '^', '3', '-1', ')', '/', '...
# 20               3594  ['좌표평', '위', '세', '점', '`', 'O', '(', '0', ','...
# 23               3427  ['좌표평', '위', '두', '점', '`', 'A', '(', '1', ','...
#
#                                            math_field  \
# 4   ['(x, y)->(x+2, y-7)', 'y=x^2', 'y=x^2+px+q', ...
# 15  ['ax^2+bx+c', '(x-p)', '(x+q)', 'ax^2+bx+c', '...
# 17                      ['(2060^3-1)/(2061xx2060+1)']
# 20  ['O(0, 0)', 'A(2, 3)', 'B(-3, 5)', '△OAB', '(a...
# 23           ['A(1, 1)', 'B(3, -2)', 'y', 'Q', 'ABQ']
#
#                                          hangul_field  wrong_word2vec  \
# 4   ['평행이동', '의해', '포물선', '평행이동하였더', '포물선', '되었다',...               0
# 15  ['오른쪽', '조립제법', '나눈', '몫', '다시', '나누', '과정', '...               0
# 17                                              ['값']               0
# 20  ['좌표평', '위', '세', '점', '꼭짓점', '하', '수심', '좌표',...               0
# 23  ['좌표평', '위', '두', '점', '축', '위', '움직이', '점', '...               0
#
#     wrong_tfidf
# 4             1
# 15            1
# 17            1
# 20            1
# 23            1

# %% [markdown]
# ## BERT 모델로 예측하지 못한 경우

# %%
wrong_list_bert = np.zeros(len(df_train_label), dtype=int)

for i in df_train_label.index:
    if df_train_label.loc[i, 'chapter'] != df_train_label.loc[i, 'bert_80_pred_chapter']:
        wrong_list_bert[i] = 1
        
df_train_label['wrong_bert'] = wrong_list_bert
print("BERT가 예측하지 못한 문제 개수: {}/{}".format(sum(wrong_list_bert), df_train_label.shape[0]))
df_train_label[df_train_label['wrong_bert']==1].head()
# Out:
# BERT가 예측하지 못한 문제 개수: 13/5364
#       chapter bert_80_pred_chapter tfidf_pred_chapter  \
# 47    H1S1-04              HSU1-06            H1S1-01
# 792   HSU1-06              H1S2-01            H1S1-01
# 839   H1S2-06              HSU1-05            H1S1-01
# 1324  H1S2-01              HSU1-01            H1S1-01
# 1460  H1S2-04              HSU1-06            H1S1-01
#
#                   word2vec_pred_chapter            text        qtid  \
# 47    ['H1S2-03', 'H1S2-01', 'HSU1-05']     다음 중 옳은 것은?  H1S1-04-01
# 792   ['H1S2-03', 'H1S2-01', 'HSU1-05']     다음 중 옳은 것은?  HSU1-06-02
# 839   ['H1S2-03', 'H1S2-01', 'HSU1-05']  다음 중 옳지 않은 것은?  H1S2-06-02
# 1324  ['H1S2-03', 'H1S2-01', 'HSU1-05']     다음 중 옳은 것은?  H1S2-01-05
# 1460  ['H1S2-03', 'H1S2-01', 'HSU1-05']     다음 중 옳은 것은?  H1S2-04-08
#
#                  name            word2vec_pred_name  qplay_question_id  \
# 47         복소수의 뜻과 분류  ['명제', '집합의 뜻', '호도법과 육십분법']               4371
# 792   삼각함수 값의 대소관계 판별  ['명제', '집합의 뜻', '호도법과 육십분법']               7055
# 839           제곱근의 성질  ['명제', '집합의 뜻', '호도법과 육십분법']              16324
# 1324     유한집합의 원소의 개수  ['명제', '집합의 뜻', '호도법과 육십분법']              19511
# 1460       항등함수와 상수함수  ['명제', '집합의 뜻', '호도법과 육십분법']              24743
#
#                                 token math_field                hangul_field  \
# 47         ['다음', '중', '옳', '것', '?']         []       ['다음', '중', '옳', '것']
# 792        ['다음', '중', '옳', '것', '?']         []       ['다음', '중', '옳', '것']
# 839   ['다음', '중', '옳', '않', '것', '?']         []  ['다음', '중', '옳', '않', '것']
# 1324       ['다음', '중', '옳', '것', '?']         []       ['다음', '중', '옳', '것']
# 1460       ['다음', '중', '옳', '것', '?']         []       ['다음', '중', '옳', '것']
#
#       wrong_word2vec  wrong_tfidf  wrong_bert
# 47                 1            1           1
# 792                1            1           1
# 839                1            1           1
# 1324               0            1           1
# 1460               1            1           1

# %%
wrong_bert = df_train_label[df_train_label['wrong_bert']==1]
wrong_bert.reset_index(inplace=True)
wrong_bert
# Out:
#     index  chapter bert_80_pred_chapter tfidf_pred_chapter  \
# 0   47     H1S1-04  HSU1-06              H1S1-01
# 1   792    HSU1-06  H1S2-01              H1S1-01
# 2   839    H1S2-06  HSU1-05              H1S1-01
# 3   1324   H1S2-01  HSU1-01              H1S1-01
# 4   1460   H1S2-04  HSU1-06              H1S1-01
# 5   1629   H1S1-03  HSU1-05              H1S1-01
# 6   1915   H1S1-03  HSU1-01              H1S1-01
# 7   2209   H1S2-04  H1S2-05              H1S2-04
# 8   2229   H1S2-01  HSU1-01              H1S1-01
# 9   2304   H1S2-06  H1S2-04              H1S2-06
# 10  2309   H1S2-02  H1S2-01              H1S2-02
# 11  2598   HSU1-05  H1S2-06              H1S1-01
# 12  4605   HSU1-06  H1S2-01              H1S1-01
#
#                 word2vec_pred_chapter  \
# 0   ['H1S2-03', 'H1S2-01', 'HSU1-05']
# 1   ['H1S2-03', 'H1S2-01', 'HSU1-05']
# 2   ['H1S2-03', 'H1S2-01', 'HSU1-05']
# 3   ['H1S2-03', 'H1S2-01', 'HSU1-05']
# 4   ['H1S2-03', 'H1S2-01', 'HSU1-05']
# 5   ['H1S2-03', 'H1S2-01', 'HSU1-05']
# 6   ['H1S2-03', 'H1S2-01', 'HSU1-05']
# 7   ['H1S2-05', 'H1S2-05', 'H1S2-04']
# 8   ['H1S2-03', 'H1S2-01', 'HSU1-05']
# 9   ['H1S2-06', 'H1S2-04', 'H1S2-05']
# 10  ['H1S2-02', 'H1S2-02', 'H1S2-02']
# 11  ['H1S2-03', 'H1S2-01', 'HSU1-05']
# 12  ['H1S2-03', 'H1S2-01', 'HSU1-05']
#
#                                                                                                             text  \
# 0   다음 중 옳은 것은?
# 1   다음 중 옳은 것은?
# 2   다음 중 옳지 않은 것은?
# 3   다음 중 옳은 것은?
# 4   다음 중 옳은 것은?
# 5   다음 중 옳지 않은 것은?
# 6   다음 중 옳은 것은?
# 7   함수 `f(x)=(x-1)/x`에 대하여 `f^1=f`, `f^(n+1)=f@f^n` (`n`은 자연수)이고, `f^2018(x)`의 역함수를 `g(x)`라고 할 때, `g(2018)`의 값은?
# 8   다음 중 옳은 것은?
# 9   정의역이 `{x| x > 1}`인 두 함수<br/>`f(x)=(x+2)/(x-1)`, `g(x)=sqrt(2x-2)+1`<br/>에 대하여 `(f@(g@f)^-1@f)(2)`의 값은?
# 10  `n(A)=7`, `n(AuuB)=12`, `n(AnnB)=4`일 때, 집합 `B`의 원소의 개수를 구하여라.
# 11  다음 중 옳지 않은 것은?
# 12  다음 중 옳은 것은?
#
#           qtid              name  \
# 0   H1S1-04-01  복소수의 뜻과 분류
# 1   HSU1-06-02  삼각함수 값의 대소관계 판별
# 2   H1S2-06-02  제곱근의 성질
# 3   H1S2-01-05  유한집합의 원소의 개수
# 4   H1S2-04-08  항등함수와 상수함수
# 5   H1S1-03-01  인수분해의 기본
# 6   H1S1-03-01  인수분해의 기본
# 7   H1S2-04-16  역함수의 정의
# 8   H1S2-01-05  유한집합의 원소의 개수
# 9   H1S2-06-14  무리함수의 합성함수와 역함수
# 10  H1S2-02-14  유한집합의 원소의 개수와 활용
# 11  HSU1-05-03  호도법과 육십분법
# 12  HSU1-06-02  삼각함수 값의 대소관계 판별
#
#                                     word2vec_pred_name  qplay_question_id  \
# 0   ['명제', '집합의 뜻', '호도법과 육십분법']                        4371
# 1   ['명제', '집합의 뜻', '호도법과 육십분법']                        7055
# 2   ['명제', '집합의 뜻', '호도법과 육십분법']                        16324
# 3   ['명제', '집합의 뜻', '호도법과 육십분법']                        19511
# 4   ['명제', '집합의 뜻', '호도법과 육십분법']                        24743
# 5   ['명제', '집합의 뜻', '호도법과 육십분법']                        4950
# 6   ['명제', '집합의 뜻', '호도법과 육십분법']                        4471
# 7   ['유리함수의 합성', '유리함수의 합성함수와 역함수', '합성함수와 역함수']        25074
# 8   ['명제', '집합의 뜻', '호도법과 육십분법']                        21213
# 9   ['무리함수의 합성함수와 역함수', '역함수의 성질', '유리함수의 합성']          24967
# 10  ['유한집합의 원소의 개수와 활용', '합집합과 교집합', '새롭게 약속된 집합의 연산']  20786
# 11  ['명제', '집합의 뜻', '호도법과 육십분법']                        7946
# 12  ['명제', '집합의 뜻', '호도법과 육십분법']                        7059
#
#                                                                                                                                                                                                                                                                                                                                                                            token  \
# 0   ['다음', '중', '옳', '것', '?']
# 1   ['다음', '중', '옳', '것', '?']
# 2   ['다음', '중', '옳', '않', '것', '?']
# 3   ['다음', '중', '옳', '것', '?']
# 4   ['다음', '중', '옳', '것', '?']
# 5   ['다음', '중', '옳', '않', '것', '?']
# 6   ['다음', '중', '옳', '것', '?']
# 7   ['함수', '`', 'f', '(', 'x', ')', '=', '(', 'x', '-1', ')', '/', 'x', '`', '대하', '`', 'f', '^', '1', '=', 'f', '`,', '`', 'f', '^', '(', 'n', '+', '1', ')', '=', 'f', '@', 'f', '^', 'n', '`', '(', '`', 'n', '`', '자연수', ')', ',', '`', 'f', '^', '2018', '(', 'x', ')', '`', '역함수', '`', 'g', '(', 'x', ')', '`', '할', '때', ',', '`', 'g', '(', '2018', ')', '`', '값', '?']
# 8   ['다음', '중', '옳', '것', '?']
# 9   ['정의역', '`', '{', 'x', '|', 'x', '>', '1', '}', '`', '두', '함수', '`', 'f', '(', 'x', ')', '=', '(', 'x', '+', '2', ')', '/', '(', 'x', '-1', ')', '`,', '`', 'g', '(', 'x', ')', '=', 'sqrt', '(', '2', 'x', '-2', ')', '+', '1', '`', '대하', '`', '(', 'f', '@', '(', 'g', '@', 'f', ')', '^', '-1', '@', 'f', ')', '(', '2', ')', '`', '값', '?']
# 10  ['`', 'n', '(', 'A', ')', '=', '7', '`,', '`', 'n', '(', 'A', 'uu', 'B', ')', '=', '12', '`,', '`', 'n', '(', 'A', 'nn', 'B', ')', '=', '4', '`', '일', '때', ',', '집합', '`', 'B', '`', '원소', '개수', '구하여', '.']
# 11  ['다음', '중', '옳', '않', '것', '?']
# 12  ['다음', '중', '옳', '것', '?']
#
#                                                                          math_field  \
# 0   []
# 1   []
# 2   []
# 3   []
# 4   []
# 5   []
# 6   []
# 7   ['f(x)=(x-1)/x', 'f^1=f', 'f^(n+1)=f@f^n', 'n', 'f^2018(x)', 'g(x)', 'g(2018)']
# 8   []
# 9   ['{x| x > 1}', 'f(x)=(x+2)/(x-1)', 'g(x)=sqrt(2x-2)+1', '(f@(g@f)^-1@f)(2)']
# 10  ['n(A)=7', 'n(AuuB)=12', 'n(AnnB)=4', 'B']
# 11  []
# 12  []
#
#                                  hangul_field  wrong_word2vec  wrong_tfidf  \
# 0   ['다음', '중', '옳', '것']                      1               1
# 1   ['다음', '중', '옳', '것']                      1               1
# 2   ['다음', '중', '옳', '않', '것']                 1               1
# 3   ['다음', '중', '옳', '것']                      0               1
# 4   ['다음', '중', '옳', '것']                      1               1
# 5   ['다음', '중', '옳', '않', '것']                 1               1
# 6   ['다음', '중', '옳', '것']                      1               1
# 7   ['함수', '대하', '자연수', '역함수', '할', '때', '값']  0               0
# 8   ['다음', '중', '옳', '것']                      0               1
# 9   ['정의역', '두', '함수', '대하', '값']              0               0
# 10  ['일', '때', '집합', '원소', '개수', '구하여']        0               0
# 11  ['다음', '중', '옳', '않', '것']                 0               1
# 12  ['다음', '중', '옳', '것']                      1               1
#
#     wrong_bert  wrong_sum
# 0   1           3
# 1   1           3
# 2   1           3
# 3   1           2
# 4   1           3
# 5   1           3
# 6   1           3
# 7   1           1
# 8   1           2
# 9   1           1
# 10  1           1
# 11  1           2
# 12  1           3

# %%
# index 7,9,10 을 제외한 나머지 문제는 '다음 중 옳은 것은/다음 중 옳지 않은 것은'
wrong_bert.loc[7,:]
# Out:
# index                    2209
# chapter                  H1S2-04
# bert_80_pred_chapter     H1S2-05
# tfidf_pred_chapter       H1S2-04
# word2vec_pred_chapter    ['H1S2-05', 'H1S2-05', 'H1S2-04']
# text                     함수 `f(x)=(x-1)/x`에 대하여 `f^1=f`, `f^(n+1)=f@f^n` (`n`은 자연수)이고, `f^2018(x)`의 역함수를 `g(x)`라고 할 때, `g(2018)`의 값은?
# qtid                     H1S2-04-16
# name                     역함수의 정의
# word2vec_pred_name       ['유리함수의 합성', '유리함수의 합성함수와 역함수', '합성함수와 역함수']
# qplay_question_id        25074
# token                    ['함수', '`', 'f', '(', 'x', ')', '=', '(', 'x', '-1', ')', '/', 'x', '`', '대하', '`', 'f', '^', '1', '=', 'f', '`,', '`', 'f', '^', '(', 'n', '+', '1', ')', '=', 'f', '@', 'f', '^', 'n', '`', '(', '`', 'n', '`', '자연수', ')', ',', '`', 'f', '^', '2018', '(', 'x', ')', '`', '역함수', '`', 'g', '(', 'x', ')', '`', '할', '때', ',', '`', 'g', '(', '2018', ')', '`', '값', '?']
# math_field               ['f(x)=(x-1)/x', 'f^1=f', 'f^(n+1)=f@f^n', 'n', 'f^2018(x)', 'g(x)', 'g(2018)']
# hangul_field             ['함수', '대하', '자연수', '역함수', '할', '때', '값']
# wrong_word2vec           0
# wrong_tfidf              0
# wrong_bert               1
# wrong_sum                1
# Name: 7, dtype: object

# %% [markdown]
# ## wrong_sum

# %%
# wrong_sum: 3가지 모델에서 잘못 예측한 경우의 count
df_train_label['wrong_sum'] = df_train_label['wrong_word2vec'] + df_train_label['wrong_tfidf'] + df_train_label['wrong_bert']
df_train_label['wrong_sum'].value_counts()
# Out:
# 0    3974
# 1    1187
# 2     196
# 3       7
# Name: wrong_sum, dtype: int64

# %% [markdown]
# ---
#
# # 3가지 모델 모두에서 예측하지 못한 경우
#
# + 모두 `'다음 중 옳은 것은?'/ '다음 중 옳지 않은 것은'` 에 대한 문제.
#     + chapter(실제) : H1S1-03, H1S1-04, H1S2-04, H1S2-06, HSU1-06
#     + BERT: 다양한 값을 예측했음. But how?
#     + tfidf_pred_chapter: H1S1-01
#     + word2vec_pred_chapter: 'H1S2-03', 'H1S2-01', 'HSU1-05'
#
# + BERT가 그나마 가장 좋은 예측... 별다른 방법이 없을 것 같다.

# %%
print("3가지 모델 모두에서 예측하지 못한 경우:", len(df_train_label[df_train_label['wrong_sum'] == 3]))
df_train_label[df_train_label['wrong_sum'] == 3][['qplay_question_id', 'chapter', 'text', 'bert_80_pred_chapter', 'tfidf_pred_chapter', 'word2vec_pred_chapter']]
# Out:
# 3가지 모델 모두에서 예측하지 못한 경우: 7
#       qplay_question_id  chapter            text bert_80_pred_chapter  \
# 47                 4371  H1S1-04     다음 중 옳은 것은?              HSU1-06
# 792                7055  HSU1-06     다음 중 옳은 것은?              H1S2-01
# 839               16324  H1S2-06  다음 중 옳지 않은 것은?              HSU1-05
# 1460              24743  H1S2-04     다음 중 옳은 것은?              HSU1-06
# 1629               4950  H1S1-03  다음 중 옳지 않은 것은?              HSU1-05
# 1915               4471  H1S1-03     다음 중 옳은 것은?              HSU1-01
# 4605               7059  HSU1-06     다음 중 옳은 것은?              H1S2-01
#
#      tfidf_pred_chapter              word2vec_pred_chapter
# 47              H1S1-01  ['H1S2-03', 'H1S2-01', 'HSU1-05']
# 792             H1S1-01  ['H1S2-03', 'H1S2-01', 'HSU1-05']
# 839             H1S1-01  ['H1S2-03', 'H1S2-01', 'HSU1-05']
# 1460            H1S1-01  ['H1S2-03', 'H1S2-01', 'HSU1-05']
# 1629            H1S1-01  ['H1S2-03', 'H1S2-01', 'HSU1-05']
# 1915            H1S1-01  ['H1S2-03', 'H1S2-01', 'HSU1-05']
# 4605            H1S1-01  ['H1S2-03', 'H1S2-01', 'HSU1-05']

# %% [markdown]
# 모두 `'다음 중 옳은 것은?'/ '다음 중 옳지 않은 것은'` 에 대한 문제를 맞춘 경우?

# %%
search = '다음 중 옳은 것은?'

# 조건를 충족하는 데이터를 필터링
subset_df = df_train_label[df_train_label['text'] == search]

print("search 개수:", subset_df.shape[0])
print(subset_df['chapter'].value_counts())
subset_df[['qplay_question_id', 'chapter', 'text', 'wrong_bert', 'wrong_tfidf', 'wrong_word2vec', 'wrong_sum']]
# Out:
# search 개수: 10
# HSU1-01    3
# H1S2-01    2
# HSU1-06    2
# H1S2-04    1
# H1S1-03    1
# H1S1-04    1
# Name: chapter, dtype: int64
#       qplay_question_id  chapter         text  wrong_bert  wrong_tfidf  \
# 35                 5459  HSU1-01  다음 중 옳은 것은?           0            1
# 47                 4371  H1S1-04  다음 중 옳은 것은?           1            1
# 792                7055  HSU1-06  다음 중 옳은 것은?           1            1
# 1324              19511  H1S2-01  다음 중 옳은 것은?           1            1
# 1460              24743  H1S2-04  다음 중 옳은 것은?           1            1
# 1561               5473  HSU1-01  다음 중 옳은 것은?           0            1
# 1609               5460  HSU1-01  다음 중 옳은 것은?           0            1
# 1915               4471  H1S1-03  다음 중 옳은 것은?           1            1
# 2229              21213  H1S2-01  다음 중 옳은 것은?           1            1
# 4605               7059  HSU1-06  다음 중 옳은 것은?           1            1
#
#       wrong_word2vec  wrong_sum
# 35                 1          2
# 47                 1          3
# 792                1          3
# 1324               0          2
# 1460               1          3
# 1561               1          2
# 1609               1          2
# 1915               1          3
# 2229               0          2
# 4605               1          3

# %%
search = '다음 중 옳지 않은 것은?'

# 조건를 충족하는 데이터를 필터링
subset_df = df_train_label[df_train_label['text'] == search]

print("search 개수:", subset_df.shape[0])
print(subset_df['chapter'].value_counts())
subset_df[['qplay_question_id', 'chapter', 'text', 'wrong_bert', 'wrong_tfidf', 'wrong_word2vec', 'wrong_sum']]
# Out:
# search 개수: 5
# HSU1-05    2
# H1S2-06    1
# H1S1-03    1
# HSU1-06    1
# Name: chapter, dtype: int64
#       qplay_question_id  chapter            text  wrong_bert  wrong_tfidf  \
# 193                8044  HSU1-05  다음 중 옳지 않은 것은?           0            1
# 839               16324  H1S2-06  다음 중 옳지 않은 것은?           1            1
# 1629               4950  H1S1-03  다음 중 옳지 않은 것은?           1            1
# 2598               7946  HSU1-05  다음 중 옳지 않은 것은?           1            1
# 2696               7024  HSU1-06  다음 중 옳지 않은 것은?           0            1
#
#       wrong_word2vec  wrong_sum
# 193                0          1
# 839                1          3
# 1629               1          3
# 2598               0          2
# 2696               1          2

# %% [markdown]
# ---
#
# # 2가지 모델에서 예측하지 못한 경우
#
# + 모두 `'다음 중 옳은 것은?'/ '다음 중 옳지 않은 것은'` 에 대한 문제.
#     + chapter(실제) : H1S1-03, H1S1-04, H1S2-04, H1S2-06, HSU1-06
#     + BERT: 다양한 값을 예측했음. But how?
#     + tfidf_pred_chapter: H1S1-01
#     + word2vec_pred_chapter: 'H1S2-03', 'H1S2-01', 'HSU1-05'
#
# + BERT가 그나마 가장 좋은 예측... 별다른 방법이 없을 것 같다.

# %%
pd.set_option('display.max_rows', None, 'display.max_columns', None, 'display.max_colwidth', -1)

print("2가지 모델 모두에서 예측하지 못한 경우:", len(df_train_label[df_train_label['wrong_sum'] == 2]))
df_train_label[df_train_label['wrong_sum'] == 2][['qplay_question_id', 'chapter', 'text', 'bert_80_pred_chapter', 'tfidf_pred_chapter', 'word2vec_pred_chapter']]
# Out:
# 2가지 모델 모두에서 예측하지 못한 경우: 196
# C:\Users\sdn11\Anaconda\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   """Entry point for launching an IPython kernel.
#       qplay_question_id  chapter  \
# 35    5459               HSU1-01
# 117   4271               H1S1-12
# 143   7295               HSU1-03
# 184   4087               H1S1-08
# 189   5434               H1S1-07
# 218   4727               H1S1-10
# 229   4214               H1S1-07
# 265   8553               HSU1-01
# 282   7056               HSU1-09
# 298   7215               HSU1-06
# 311   4583               H1S1-12
# 317   3657               H1S1-08
# 348   9382               HSTA-04
# 376   7858               HSU1-01
# 402   8343               HSU1-02
# 422   8099               HSU1-02
# 447   8137               HSU1-04
# 451   9206               HSTA-06
# 452   9485               HSU1-01
# 464   9630               HSTA-05
# 472   8254               HSU1-04
# 478   9083               HSTA-01
# 483   3812               H1S1-07
# 535   9601               HSTA-02
# 536   9726               HSTA-02
# 578   9522               HSTA-03
# 591   8527               HSU1-02
# 596   7192               HSU1-08
# 635   8735               HSU1-02
# 684   18099              H1S2-05
# 700   4026               H1S1-02
# 806   19973              H1S2-05
# 838   25020              H1S2-05
# 861   3922               H1S1-08
# 862   4014               H1S1-03
# 866   4554               H1S1-03
# 925   8389               HSU1-10
# 934   4561               H1S1-01
# 935   4900               H1S1-04
# 977   18363              H1S2-03
# 984   7894               HSU1-04
# 991   9193               HSTA-06
# 1022  25039              H1S2-04
# 1043  7338               HSU1-10
# 1116  22353              H1S2-05
# 1121  24260              H1S2-04
# 1196  25155              H1S2-07
# 1223  25251              H1S2-05
# 1229  24280              H1S2-06
# 1242  24888              H1S2-04
# 1285  25223              H1S2-07
# 1286  20309              H1S2-07
# 1324  19511              H1S2-01
# 1333  24754              H1S2-05
# 1348  17875              H1S2-05
# 1386  24150              H1S2-05
# 1410  19812              H1S2-03
# 1529  22294              H1S2-04
# 1533  20416              H1S2-03
# 1550  12313              HSU1-08
# 1561  5473               HSU1-01
# 1564  3633               H1S1-07
# 1569  4600               H1S1-12
# 1609  5460               HSU1-01
# 1639  3711               H1S1-03
# 1692  9280               HSTA-05
# 1710  3814               H1S1-06
# 1793  4850               H1S1-06
# 1804  8899               HSU1-03
# 1817  7983               HSU1-03
# 1848  8384               HSTA-03
# 1865  9749               HSTA-06
# 1892  9357               HSTA-04
# 1912  3575               H1S1-09
# 1956  8290               HSU1-03
# 1957  8380               HSU1-10
# 1972  9001               HSU1-03
# 1993  7855               HSU1-02
# 1997  9106               HSTA-02
# 2033  8145               HSU1-03
# 2089  19570              H1S2-02
# 2118  24482              H1S2-07
# 2190  24798              H1S2-06
# 2212  22308              H1S2-05
# 2229  21213              H1S2-01
# 2238  24406              HSTA-02
# 2258  18750              H1S2-03
# 2287  24330              H1S2-06
# 2339  5018               H1S1-01
# 2355  25307              H1S2-04
# 2357  24245              H1S2-07
# 2363  24508              H1S2-07
# 2368  25119              H1S2-06
# 2372  24207              H1S2-07
# 2380  18647              H1S2-04
# 2448  19995              H1S2-05
# 2550  8481               HSU1-08
# 2563  4905               H1S1-04
# 2585  3897               H1S1-11
# 2598  7946               HSU1-05
# 2620  7146               HSU1-08
# 2657  5406               H1S1-09
# 2676  8310               HSU1-03
# 2696  7024               HSU1-06
# 2755  9760               HSTA-03
# 2805  8812               HSU1-06
# 2836  8110               HSU1-06
# 2863  8223               HSU1-06
# 2866  8874               HSU1-03
# 2885  9741               HSTA-02
# 2910  14711              HSU1-03
# 2951  20305              H1S2-05
# 3000  7607               HSU1-06
# 3020  16933              H1S2-05
# 3061  4567               H1S1-02
# 3067  7397               HSU1-09
# 3172  24964              H1S2-04
# 3201  25271              H1S2-07
# 3209  20190              H1S2-02
# 3214  24146              H1S2-07
# 3253  18729              H1S2-06
# 3264  24715              H1S2-04
# 3291  7442               HSU1-10
# 3305  7291               HSU1-02
# 3320  9358               HSTA-04
# 3363  12358              H1S1-08
# 3377  9636               HSTA-02
# 3379  18038              H1S2-05
# 3398  17900              H1S2-05
# 3403  19147              H1S2-02
# 3480  24610              HSTA-02
# 3606  7759               HSU1-03
# 3621  3784               H1S1-06
# 3633  7947               HSU1-03
# 3647  7912               HSU1-04
# 3662  7841               HSU1-01
# 3663  8302               HSU1-03
# 3714  4596               H1S1-12
# 3726  7773               HSU1-03
# 3764  7945               HSU1-03
# 3769  9647               HSTA-02
# 3875  9064               HSTA-01
# 3922  7883               HSU1-01
# 3944  4711               H1S1-11
# 3959  14828              H1S2-01
# 3996  8513               HSU1-02
# 4044  15222              H1S2-01
# 4118  20370              H1S2-07
# 4145  25089              H1S2-07
# 4153  8237               HSU1-03
# 4180  24293              H1S2-03
# 4196  18204              H1S2-05
# 4256  24187              H1S2-07
# 4272  24784              H1S2-07
# 4277  24669              H1S2-03
# 4284  20561              H1S2-04
# 4424  3544               H1S1-04
# 4437  3399               H1S1-07
# 4442  4243               H1S1-02
# 4452  3652               H1S1-07
# 4453  3796               H1S1-08
# 4475  4555               H1S1-03
# 4477  5472               HSU1-01
# 4486  4859               H1S1-06
# 4504  4585               H1S1-12
# 4532  7708               HSU1-04
# 4561  4514               H1S1-05
# 4598  8519               HSU1-02
# 4631  8563               HSU1-01
# 4644  8746               HSU1-11
# 4665  5038               H1S1-03
# 4686  4536               H1S1-03
# 4717  9537               HSTA-02
# 4721  7827               HSU1-01
# 4732  5056               H1S1-01
# 4742  6652               HSTA-03
# 4757  7495               HSU1-08
# 4796  8060               HSTA-06
# 4845  8721               HSU1-03
# 4920  20383              H1S2-05
# 4950  8139               HSU1-03
# 5008  19182              H1S2-05
# 5009  19506              H1S2-07
# 5055  24868              H1S1-07
# 5108  18869              H1S2-07
# 5111  24189              H1S2-07
# 5121  7893               HSU1-01
# 5138  22136              H1S2-04
# 5149  24215              H1S2-07
# 5214  24268              H1S1-06
# 5238  24365              H1S2-04
# 5262  14710              H1S1-02
# 5272  21940              H1S2-03
# 5285  24492              H1S2-05
# 5288  24848              H1S2-05
# 5358  31127              H1S2-06
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         text  \
# 35    다음 중 옳은 것은?
# 117   직선 `2x-y=0`을 직선 `x+y-3=0`에 대하여 대칭이동한 직선의 방정식이 `x+ay+b=0`일 때, 상수 `a`, `b`에 대하여 `a^2+b^2`의 값은?
# 143   두 집합 `A={x|5^(2x)-20xx5^x-125 <= 0}`, `B={x|(1/9)^x-8(1/3)^x-9 < 0}`에 대하여 집합 `AnnB`에 속하는 모든 정수 원소의 합을 구하시오.
# 184   이차방정식 `x^2+(a-1)x+(a-1)=0`이 중근을 가질 때, 모든 실수 `a`의 값의 합은?
# 189   영희와 준희가 사탕 주머니에서 각각 사탕을 `1`개 이상 꺼냈다. 꺼낸 사탕 개수를 기준으로 철수에게는 영희와 준희가 꺼낸 사탕 개수의 합의 `4`배 만큼을 주고, 나미에게는 영희가 꺼낸 사탕 개수의 제곱과 준희가 꺼낸 사탕 개수의 제곱의 합만큼을 주고, 진수에게는 영희가 꺼낸 사탕 개수와 준희가 꺼낸 사탕 개수의 곱의 `2`배 만큼을 주었다고 할 때 철수, 나미, 진수에게 준 사탕 개수의 합이 `12`이다. 이때 영희가 꺼낸 사탕 개수는?
# 218   네 점 `O(0, 0)`, `A(4, 1)`, `B(6, 8)`, `C(2, 7)`을 꼭짓점으로 하는 사각형 `OABC`의 넓이는?
# 229   다음 그림과 같이 서로 외접하는 작은 두 구가 반지름의 길이가 `6`인 큰 구에 내접하고 있다. 작은 두 구의 겉넓이의 합이 `112pi`일 때, 작은 두 구의 부피의 합은 `kpi`이다. 실수 `k`의 값을 구하시오.
# 265   `a > 0`, `b > 0`일 때, `root4 (ab) divide root4 (a^3b^2) xx sqrt(asqrtb)`을 간단히 하면?
# 282   `A`, `B` 두 사람은 각각 같은 농도의 식염수 `9`L씩 가지고 있다. `A`는 식염수 `6`L를 버리고 물 `6`L를 넣는 시행을 반복하고, `B`는 식염수 `8`L를 버리고 물 `8`L를 넣는 시행을 반복한다. `A`, `B`가 시행을 각각 `p`번, `q`번 반복하여 얻은 식염수의 농도가 서로 같을 때, `p:q`를 가장 간단한 자연수의 비로 나타내면?
# 298   예각삼각형 `ABC`의 세 내각의 크기를 `A`, `B`, `C`라고 할 때, 다음 중 항상 옳은 것이 아닌 것을 고르면?
# 311   직선 `y=2x+3`과 `x`축에 대하여 대칭인 직선에 수직이고 점 `(3, -2)`를 지나는 직선의 방정식을 `ax+by+c=0`이라 할 때, `a-b+c`의 값은? (단, `a`, `b`, `c`는 정수이며 `a > 0`)
# 317   `x`에 대한 이차방정식 `k^2x^2+(2k-1)x+1=0`이 서로 다른 두 실근을 가질 때, 실수 `k`이 될 수 없는 것을 고르시오. (답 2개)
# 348   한 개의 주사위를 던질 때, 짝수의 눈이 나오는 사건을 `A`, `n(1 <= n <= 6)`의 약수의 눈이 나오는 사건을 `B`라 하자. 두 사건 `A`와 `B`가 서로 독립이 되도록 하는 모든 자연수 `n`의 값의 합을 구하시오.
# 376   원기둥 모양의 수도관에서 단면인 원의 넓이를 `S`, 원의 둘레의 길이를 `L`이라 하고, 수도관의 기울기를 `I`라 하자. 이 수도관에서 물이 가득 찬 상채로 흐를 때 물의 속력을 `v`라 하면 `v = c(S/L)^(2/3)*I^(1/2)`(단, `c`는 상수)이 성립한다고 한다.<br/>단면인 원의 반지름의 길이가 각각 `a`, `b`인 원기둥 모양의 두 수도관 `A`, `B`에서 물이 가득 찬 상태로 흐르고 있다. 두 수도관 `A`, `B`의 기울기가 각각 `0.01`, `0.04`이고, 흐르는 물의 속력을 각각 `v_A`, `v_B`라고 하자. `(v_A)/(v_B)=2`일 때, `a/b`의 값은?<br/>단, 두 수도관 `A`, `B`에 대한 상수 `c`의 값은 서로 같다.)
# 402   실수 `x`, `y`에 대하여 `24^x=8`, `3^y=64`일 때, `3/x-6/y`의 값은?
# 422   두 실수 `x`, `y`에 대하여 `6^x=7`, `294^y=343`이 성립할 때, `1/x-3/y`의 값은?
# 447   `A=3`, `B=log_3{::}15`, `C=log_9{::}25`일 때, 다음 중`A`, `B`, `C`의 대소 관계로 옳은 것은?
# 451   서로 다른 동전 세 개를 동시에 `300`번 던질 때, 세 개 모두 같은 면이 나오는 횟수가 `90`번 이하일 확률을 아래의 정규분포표를 이용하여 구하면?
# 452   거듭제곱근에 대한 설명 중 옳은 것은?
# 464   확률변수 `X`의 확률질량함수가 `P(X=x)=k/(sqrt (n+1)+sqrt n) (x=1,2,cdots,15)`일 때, 상수 `k`의 값은?
# 472   지진에 의해서 발생된 에너지의 양은 보통 리히터 규모로 나타나는데, 발생되는 에너지가 `x` `erg`(에르그)인 지진의 리히터 규모를 `M`이라고 할 때, `logx = 11.8 + 1.5M`이 성립한다고 한다. 리히터 규모가 `7`인 지진의 에너지는 규모가 `a`인 지진의 에너지의 `1000`배이다. `a`의 값은?
# 478   영어 단어 `suc{::}cess`의 `7`개의 알파벳을 일렬로 나열할 때, 양쪽 끝에 알파벳 '`c`'가 오는 경우의 수는?
# 483   넓이가 밑변과 높이의 합의 `4`배보다 `6`만큼 작은 평행사변형 중 밑변과 높이가 모두 자연수인 평행사변형의 개수는?
# 535   똑같은 공 `12`개를 `4`개의 바구니 `A`, `B`, `C`, `D`에 나누어 담으려고 한다. 바구니 `A`에는 `2`개 이상, 바구니 `B`에는 `3`개 이상의 공을 담는 방법의 수는? (단, 빈 바구니가 있을 수 있다.)
# 536   빨간색, 파란색, 노란색 색연필이 각각 `14`개 이상씩 있다. `3`가지 색의 색연필을 적어도 하나씩 포함하여 `14`개의 색연필을 선택하는 방법의 수는? (단, 같은 색의 색연필은 서로 구별이 되지 않는다.)
# 578   집합 `X={1, 2, 3, 4, 5}`에 대하여 함수 `f : X->X` 중에서 `f(1)=3`이고, 일대일대응인 함수 `f`의 개수는?
# 591   자연수 `N`에 대하여 `logN`의 정수부분을 `f(N)`이라고 할 때, `f(2)+f(4)+f(6)+...f(1004)`의 값을 구하시오.
# 596   수열 `a`,`-1/2`, `1/2`, `b`가 등차수열일 때, `a+b`의 값은?
# 635   `[log_(2)1]+[log_(2)2]+[log_(2)3]+cdots+[log_(2)256]`의 값을 구하여라. (단, `[x]`는 `x`를 넘지 않는 최대의 정수이다.)
# 684   `x/(2y+3z)=(2y)/(3z+x)=(3z)/(x+2y)=k`를 만족시키는 모든 `k`의 값의 합은?
# 700   사차다항식 `f(x)`가 `f(1)=1/2`, `f(2)=3/4`, `f(3)=5/6`, `f(4)=7/8`, `f(5)=9/10`를 만족할 때, `f(7)`의 값은?
# 806   `2+1/(k+1/(m+1/5))=803/371`일 때, 자연수 `k`, `m`의 값에 대하여 `k+m`의 값은?
# 838   `x > 3`일 때, `x + 64 / (x-3)`는 `x = a`에서 최솟값 `b`를 갖는다. 이때 상수 `a`, `b`에 대하여 `b - a`의 값은?
# 861   다음 표는 두 식품 `A`, `B`에 대해 각각 `100g`에 들어있는 열량과 단백질의 양을 나타낸 것이다. 두 식품 `A`, `B`를 합해 `400g`을 섭취하여 열량을 `600kcal` 이하, 단백질을 `42g` 이상 얻으려 할 때, 섭취해야 하는 식품 `A`의 양은 `ag` 이상 `400g` 이하이다. 상수 `a` 값을 구하시오.
# 862   다항식 `x^4-17x^2+16`을 인수분해하였더니 `(x-a)(x-b)(x-c)(x-d)`와 같이 되었다. 네 상수 `a`, `b`, `c`, `d`에 대하여 `a < b < c < d`일 때, `bc-ad`의 값을 구하여라.
# 866   `x+y=1`, `x^2+y^2=7`을 만족하는 두 실수 `x`, `y`에 대하여 `x^5+y^5`의 값은?
# 925   수열 `{a_n}`에서 첫째항부터 제`n`항까지의 합을 `S_n`이라 하자. `S_n=n^2+4n`일 때, `1/(a_6a_7)+1/(a_7a_8)+cdots+1/(a_20a_21)=1/k`이다. `k`의 값을 구하시오.
# 934   `x+y+z=2`, `xy+yz+zx=-4`, `xyz=-1`일 때, `(x+y)(y+z)(z+x)`의 값은?
# ...
# 925   HSU1-10              H1S1-01
# 934   H1S1-01              H1S2-05
# 935   H1S1-04              H1S1-01
# 977   H1S2-03              H1S1-01
# 984   HSU1-04              H1S1-01
# 991   HSTA-06              HSTA-07
# 1022  H1S2-04              H1S1-01
# 1043  HSU1-10              H1S2-07
# 1116  H1S2-05              H1S1-01
# 1121  H1S2-04              H1S1-01
# 1196  H1S2-07              HSTA-02
# 1223  H1S2-05              H1S2-04
# 1229  H1S2-06              H1S1-01
# 1242  H1S2-04              H1S1-01
# 1285  H1S2-07              H1S1-01
# 1286  H1S2-07              HSTA-02
# 1324  HSU1-01              H1S1-01
# 1333  H1S2-05              H1S2-04
# 1348  H1S2-05              H1S1-01
# 1386  H1S2-05              H1S1-01
# 1410  H1S2-03              H1S1-01
# 1529  H1S2-04              H1S1-01
# 1533  H1S2-03              H1S1-01
# 1550  HSU1-08              H1S1-01
# 1561  HSU1-01              H1S1-01
# 1564  H1S1-07              HSU1-07
# 1569  H1S1-12              H1S1-11
# 1609  HSU1-01              H1S1-01
# 1639  H1S1-03              H1S1-01
# 1692  HSTA-05              H1S1-01
# 1710  H1S1-06              H1S1-11
# 1793  H1S1-06              H1S1-01
# 1804  HSU1-03              H1S1-01
# 1817  HSU1-03              H1S1-01
# 1848  HSTA-03              H1S1-01
# 1865  HSTA-06              H1S1-01
# 1892  HSTA-04              H1S2-07
# 1912  H1S1-09              H1S1-01
# 1956  HSU1-03              H1S1-01
# 1957  HSU1-10              H1S2-06
# 1972  HSU1-03              H1S1-01
# 1993  HSU1-02              H1S2-06
# 1997  HSTA-02              H1S2-07
# 2033  HSU1-03              H1S1-01
# 2089  H1S2-02              H1S2-07
# 2118  H1S2-07              H1S2-02
# 2190  H1S2-06              H1S2-04
# 2212  H1S2-05              H1S1-01
# 2229  HSU1-01              H1S1-01
# 2238  HSTA-02              H1S1-01
# 2258  H1S2-03              H1S1-01
# 2287  H1S2-06              H1S1-01
# 2339  H1S1-01              H1S1-02
# 2355  H1S2-04              H1S1-01
# 2357  H1S2-07              H1S1-01
# 2363  H1S2-07              H1S1-01
# 2368  H1S2-06              H1S1-01
# 2372  H1S2-07              H1S1-01
# 2380  H1S2-04              H1S1-01
# 2448  H1S2-05              H1S1-01
# 2550  HSU1-08              H1S1-01
# 2563  H1S1-04              H1S1-01
# 2585  H1S1-11              H1S1-01
# 2598  H1S2-06              H1S1-01
# 2620  HSU1-08              H1S2-07
# 2657  H1S1-09              H1S1-01
# 2676  HSU1-03              H1S2-05
# 2696  HSU1-06              H1S1-01
# 2755  HSTA-03              H1S1-01
# 2805  HSU1-06              H1S1-01
# 2836  HSU1-06              H1S1-01
# 2863  HSU1-06              H1S1-01
# 2866  HSU1-03              H1S1-01
# 2885  HSTA-02              H1S1-01
# 2910  HSU1-03              H1S1-01
# 2951  H1S2-05              H1S1-01
# 3000  HSU1-06              HSU1-05
# 3020  H1S2-05              H1S1-01
# 3061  H1S1-02              H1S1-01
# 3067  HSU1-09              H1S1-01
# 3172  H1S2-04              H1S1-01
# 3201  H1S2-07              H1S1-01
# 3209  H1S2-02              H1S1-01
# 3214  H1S2-07              H1S1-01
# 3253  H1S2-06              H1S1-01
# 3264  H1S2-04              H1S1-01
# 3291  HSU1-10              H1S2-06
# 3305  HSU1-02              H1S1-01
# 3320  HSTA-04              HSTA-03
# 3363  H1S1-08              H1S1-01
# 3377  HSTA-02              H1S1-01
# 3379  H1S2-05              H1S1-01
# 3398  H1S2-05              H1S1-01
# 3403  H1S2-02              H1S1-01
# 3480  HSTA-02              H1S2-07
# 3606  HSU1-03              H1S1-01
# 3621  H1S1-06              H1S1-01
# 3633  HSU1-03              H1S1-08
# 3647  HSU1-04              H1S1-01
# 3662  HSU1-01              H1S1-01
# 3663  HSU1-03              H1S1-01
# 3714  H1S1-12              H1S1-01
# 3726  HSU1-03              HSU1-01
# 3764  HSU1-03              H1S1-01
# 3769  HSTA-02              H1S1-01
# 3875  HSTA-01              H1S1-01
# 3922  HSU1-01              H1S1-01
# 3944  H1S1-11              H1S1-01
# 3959  H1S2-01              H1S1-01
# 3996  HSU1-02              H1S1-01
# 4044  H1S2-01              H1S1-01
# 4118  H1S2-07              H1S1-01
# 4145  H1S2-07              H1S1-01
# 4153  HSU1-03              H1S1-01
# 4180  H1S2-03              H1S1-01
# 4196  H1S2-05              H1S1-01
# 4256  H1S2-07              H1S1-01
# 4272  H1S2-07              H1S1-01
# 4277  H1S2-03              H1S1-01
# 4284  H1S2-04              H1S1-01
# 4424  H1S1-04              H1S1-01
# 4437  H1S1-07              H1S1-01
# 4442  H1S1-02              H1S1-01
# 4452  H1S1-07              H1S2-07
# 4453  H1S1-08              H1S1-06
# 4475  H1S1-03              H1S1-01
# 4477  HSU1-01              H1S1-01
# 4486  H1S1-06              H1S1-01
# 4504  H1S1-12              H1S1-01
# 4532  HSU1-04              H1S1-01
# 4561  H1S1-05              H1S1-01
# 4598  HSU1-02              H1S2-05
# 4631  HSU1-01              H1S1-01
# 4644  HSU1-11              H1S1-01
# 4665  H1S1-03              H1S1-02
# 4686  H1S1-03              H1S1-01
# 4717  HSTA-02              H1S1-01
# 4721  HSU1-01              H1S1-01
# 4732  H1S1-01              HSTA-02
# 4742  HSTA-03              H1S1-01
# 4757  HSU1-08              H1S2-07
# 4796  HSTA-06              H1S1-01
# 4845  HSU1-03              H1S1-01
# 4920  H1S2-05              H1S1-01
# 4950  HSU1-03              H1S1-01
# 5008  H1S2-05              H1S1-01
# 5009  H1S2-07              H1S1-01
# 5055  H1S1-07              H1S1-01
# 5108  H1S2-07              H1S1-01
# 5111  H1S2-07              H1S1-01
# 5121  HSU1-01              H1S1-01
# 5138  H1S2-04              H1S1-01
# 5149  H1S2-07              H1S1-01
# 5214  H1S1-06              H1S1-01
# 5238  H1S2-04              H1S1-01
# 5262  H1S1-02              H1S1-01
# 5272  H1S2-03              H1S1-01
# 5285  H1S2-05              H1S2-06
# 5288  H1S2-05              H1S1-01
# 5358  H1S2-06              H1S1-11
#
#                   word2vec_pred_chapter
# 35    ['H1S2-03', 'H1S2-01', 'HSU1-05']
# 117   ['H1S1-10', 'H1S1-10', 'H1S1-06']
# 143   ['H1S2-02', 'H1S2-03', 'H1S2-02']
# 184   ['H1S1-02', 'H1S1-05', 'H1S1-02']
# 189   ['HSTA-03', 'HSTA-03', 'HSTA-02']
# 218   ['H1S1-09', 'H1S1-09', 'H1S1-09']
# 229   ['HSU1-05', 'H1S1-05', 'H1S1-08']
# 265   ['H1S2-05', 'H1S1-03', 'H1S1-01']
# 282   ['H1S1-07', 'HSTA-04', 'HSTA-04']
# 298   ['H1S2-02', 'H1S2-02', 'H1S2-02']
# 311   ['H1S1-10', 'H1S1-06', 'H1S2-05']
# 317   ['HSU1-03', 'H1S1-05', 'H1S1-07']
# 348   ['HSTA-03', 'H1S2-02', 'H1S2-02']
# 376   ['H1S1-09', 'H1S1-09', 'H1S1-09']
# 402   ['H1S1-07', 'H1S2-03', 'H1S1-08']
# 422   ['H1S1-07', 'H1S2-03', 'H1S1-08']
# 447   ['H1S2-02', 'H1S2-02', 'H1S2-02']
# 451   ['H1S2-07', 'H1S2-07', 'HSTA-02']
# 452   ['H1S2-03', 'HSU1-05', 'H1S2-01']
# 464   ['HSTA-06', 'HSU1-10', 'H1S1-02']
# 472   ['HSU1-09', 'HSU1-02', 'HSU1-09']
# 478   ['H1S2-07', 'H1S2-07', 'H1S2-07']
# 483   ['H1S2-07', 'H1S2-07', 'H1S2-07']
# 535   ['HSTA-04', 'HSTA-03', 'H1S2-07']
# 536   ['H1S2-07', 'H1S2-07', 'HSTA-01']
# 578   ['H1S2-07', 'H1S2-04', 'HSTA-02']
# 591   ['H1S2-05', 'H1S2-05', 'H1S2-04']
# 596   ['H1S2-05', 'H1S2-03', 'H1S2-03']
# 635   ['HSU1-04', 'HSU1-04', 'HSU1-04']
# 684   ['HSU1-03', 'H1S1-01', 'HSU1-03']
# 700   ['H1S2-04', 'H1S2-05', 'H1S2-04']
# 806   ['HSU1-10', 'HSU1-01', 'HSU1-11']
# 838   ['H1S2-03', 'HSU1-06', 'H1S2-03']
# 861   ['HSU1-07', 'HSU1-07', 'HSTA-03']
# 862   ['H1S2-03', 'HSU1-06', 'H1S1-02']
# 866   ['H1S2-03', 'H1S1-06', 'H1S1-07']
# 925   ['HSU1-08', 'HSU1-09', 'HSU1-11']
# 934   ['H1S1-06', 'H1S2-03', 'H1S1-03']
# 935   ['H1S2-01', 'H1S2-03', 'HSU1-05']
# 977   ['H1S1-06', 'H1S1-07', 'HSU1-06']
# 984   ['HSU1-06', 'HSU1-03', 'HSU1-06']
# 991   ['HSTA-07', 'HSTA-07', 'HSTA-07']
# 1022  ['HSU1-06', 'H1S2-05', 'HSU1-06']
# 1043  ['H1S2-07', 'H1S2-07', 'H1S2-07']
# 1116  ['H1S1-06', 'H1S1-10', 'H1S1-09']
# 1121  ['H1S2-01', 'H1S2-03', 'HSU1-05']
# 1196  ['H1S2-01', 'H1S2-01', 'H1S2-01']
# 1223  ['HSU1-06', 'H1S2-07', 'H1S2-04']
# 1229  ['H1S2-04', 'H1S2-04', 'H1S2-04']
# 1242  ['HSU1-06', 'HSU1-03', 'HSU1-06']
# 1285  ['H1S2-04', 'H1S2-03', 'H1S2-04']
# 1286  ['H1S1-02', 'H1S1-03', 'H1S1-02']
# 1324  ['H1S2-03', 'H1S2-01', 'HSU1-05']
# 1333  ['H1S2-04', 'H1S2-04', 'H1S2-06']
# 1348  ['HSU1-03', 'H1S1-01', 'HSU1-03']
# 1386  ['H1S1-09', 'HSU1-04', 'H1S1-09']
# 1410  ['H1S1-07', 'HSU1-05', 'H1S1-07']
# 1529  ['H1S1-12', 'H1S1-12', 'H1S1-06']
# 1533  ['HSTA-04', 'HSTA-03', 'HSTA-04']
# 1550  ['H1S1-12', 'HSU1-04', 'H1S1-11']
# 1561  ['H1S2-03', 'H1S2-01', 'HSU1-05']
# 1564  ['HSU1-07', 'HSU1-07', 'H1S1-09']
# 1569  ['H1S2-05', 'H1S1-11', 'H1S1-10']
# 1609  ['H1S2-03', 'H1S2-01', 'HSU1-05']
# 1639  ['HSU1-10', 'HSU1-10', 'HSU1-10']
# 1692  ['HSTA-03', 'HSTA-04', 'HSTA-06']
# 1710  ['H1S1-11', 'H1S1-11', 'H1S1-11']
# 1793  ['H1S1-07', 'H1S1-05', 'HSU1-03']
# 1804  ['H1S2-06', 'H1S2-05', 'H1S1-12']
# 1817  ['H1S2-05', 'H1S2-05', 'H1S2-05']
# 1848  ['H1S1-09', 'H1S1-09', 'HSU1-06']
# 1865  ['HSU1-06', 'H1S2-04', 'HSU1-06']
# 1892  ['HSU1-07', 'HSU1-07', 'HSU1-07']
# 1912  ['H1S1-01', 'H1S2-05', 'HSU1-03']
# 1956  ['H1S2-05', 'H1S2-06', 'H1S2-05']
# 1957  ['HSU1-01', 'H1S1-04', 'HSU1-01']
# 1972  ['H1S1-09', 'H1S1-06', 'H1S1-10']
# 1993  ['HSU1-10', 'HSU1-01', 'HSU1-01']
# 1997  ['HSTA-01', 'H1S2-07', 'HSTA-01']
# 2033  ['HSU1-11', 'HSU1-09', 'H1S2-07']
# 2089  ['H1S2-07', 'HSTA-01', 'HSTA-01']
# 2118  ['H1S2-02', 'H1S2-02', 'H1S2-01']
# 2190  ['H1S2-04', 'H1S2-04', 'H1S2-04']
# 2212  ['HSU1-03', 'HSU1-03', 'HSU1-03']
# 2229  ['H1S2-03', 'H1S2-01', 'HSU1-05']
# 2238  ['HSU1-10', 'HSU1-10', 'HSU1-10']
# 2258  ['H1S2-01', 'H1S2-01', 'HSTA-03']
# 2287  ['H1S1-10', 'HSU1-04', 'H1S2-05']
# 2339  ['H1S1-07', 'H1S1-03', 'H1S1-02']
# 2355  ['H1S2-05', 'H1S1-10', 'H1S1-12']
# 2357  ['HSU1-09', 'HSU1-09', 'HSU1-11']
# 2363  ['H1S2-03', 'H1S2-03', 'HSU1-11']
# 2368  ['HSU1-03', 'H1S2-04', 'H1S2-04']
# 2372  ['H1S2-04', 'H1S2-03', 'HSTA-02']
# 2380  ['H1S2-01', 'H1S2-03', 'HSU1-05']
# 2448  ['HSU1-01', 'HSU1-01', 'HSU1-10']
# 2550  ['H1S1-11', 'H1S1-10', 'H1S1-11']
# 2563  ['H1S2-06', 'H1S2-06', 'H1S2-06']
# 2585  ['H1S1-03', 'H1S1-02', 'H1S1-03']
# 2598  ['H1S2-03', 'H1S2-01', 'HSU1-05']
# 2620  ['H1S2-07', 'HSTA-01', 'H1S2-07']
# 2657  ['H1S1-10', 'H1S1-06', 'H1S1-10']
# 2676  ['H1S2-06', 'H1S2-05', 'H1S2-05']
# 2696  ['H1S2-03', 'H1S2-01', 'HSU1-05']
# 2755  ['HSU1-11', 'HSU1-03', 'HSTA-04']
# 2805  ['HSU1-05', 'HSU1-05', 'HSU1-05']
# 2836  ['H1S2-03', 'H1S2-01', 'HSU1-05']
# 2863  ['H1S1-06', 'H1S2-06', 'HSU1-03']
# 2866  ['HSU1-01', 'HSU1-08', 'HSU1-02']
# 2885  ['HSU1-09', 'HSU1-08', 'HSTA-01']
# 2910  ['H1S2-04', 'H1S2-04', 'H1S2-04']
# 2951  ['HSU1-10', 'HSU1-10', 'HSU1-10']
# 3000  ['HSU1-05', 'HSU1-05', 'HSU1-05']
# 3020  ['H1S2-03', 'HSU1-06', 'H1S2-03']
# 3061  ['H1S1-01', 'H1S1-07', 'H1S1-07']
# 3067  ['H1S1-10', 'H1S1-12', 'H1S1-12']
# 3172  ['H1S1-01', 'HSU1-03', 'H1S1-03']
# 3201  ['HSU1-04', 'HSU1-04', 'HSU1-04']
# 3209  ['H1S2-01', 'H1S2-01', 'H1S2-04']
# 3214  ['H1S1-09', 'H1S1-10', 'H1S1-12']
# 3253  ['H1S2-05', 'HSU1-06', 'HSU1-03']
# 3264  ['HSTA-02', 'H1S2-02', 'H1S2-07']
# 3291  ['HSU1-01', 'HSU1-01', 'HSU1-01']
# 3305  ['H1S2-03', 'H1S1-03', 'H1S2-05']
# 3320  ['HSTA-03', 'H1S2-07', 'H1S2-07']
# 3363  ['HSTA-03', 'H1S2-07', 'H1S2-07']
# 3377  ['HSTA-01', 'H1S2-07', 'H1S2-07']
# 3379  ['HSTA-03', 'HSTA-07', 'HSTA-04']
# 3398  ['H1S1-01', 'H1S2-03', 'H1S1-06']
# 3403  ['H1S2-01', 'H1S2-01', 'H1S2-01']
# 3480  ['H1S2-07', 'HSTA-01', 'HSTA-03']
# 3606  ['H1S2-04', 'H1S2-04', 'H1S2-06']
# 3621  ['HSU1-03', 'H1S1-01', 'H1S1-01']
# 3633  ['H1S1-08', 'H1S1-08', 'H1S1-08']
# 3647  ['HSU1-06', 'H1S2-06', 'HSU1-03']
# 3662  ['H1S2-03', 'H1S2-03', 'H1S2-03']
# 3663  ['H1S1-03', 'H1S2-05', 'H1S1-04']
# 3714  ['H1S1-09', 'H1S1-10', 'H1S1-09']
# 3726  ['H1S2-05', 'H1S1-03', 'HSU1-01']
# 3764  ['H1S1-05', 'H1S1-07', 'H1S1-08']
# 3769  ['HSU1-10', 'HSU1-10', 'HSU1-10']
# 3875  ['HSTA-06', 'H1S2-04', 'H1S2-04']
# 3922  ['H1S2-03', 'H1S2-03', 'H1S2-03']
# 3944  ['H1S1-12', 'H1S1-10', 'H1S1-06']
# 3959  ['HSU1-09', 'HSU1-09', 'HSU1-08']
# 3996  ['H1S2-03', 'HSU1-06', 'HSU1-06']
# 4044  ['HSU1-08', 'HSU1-09', 'HSU1-08']
# 4118  ['H1S1-08', 'H1S1-07', 'H1S1-07']
# 4145  ['HSTA-02', 'H1S1-07', 'H1S1-06']
# 4153  ['H1S1-12', 'H1S1-12', 'H1S2-06']
# 4180  ['HSU1-07', 'H1S1-09', 'H1S1-12']
# 4196  ['HSU1-09', 'H1S1-08', 'HSU1-09']
# 4256  ['HSTA-01', 'HSTA-01', 'HSTA-01']
# 4272  ['HSTA-05', 'H1S1-09', 'HSTA-06']
# 4277  ['HSU1-04', 'H1S1-06', 'HSU1-06']
# 4284  ['H1S2-05', 'H1S2-05', 'H1S2-05']
# 4424  ['H1S2-03', 'H1S2-03', 'HSU1-01']
# 4437  ['H1S1-01', 'H1S1-06', 'H1S2-03']
# 4442  ['HSTA-02', 'HSU1-09', 'HSTA-07']
# 4452  ['H1S2-04', 'H1S2-06', 'H1S2-06']
# 4453  ['H1S2-05', 'HSU1-03', 'H1S2-05']
# 4475  ['H1S1-01', 'HSU1-03', 'H1S2-05']
# 4477  ['H1S2-03', 'H1S2-01', 'HSU1-05']
# 4486  ['H1S1-02', 'H1S1-05', 'H1S1-08']
# 4504  ['H1S1-11', 'H1S1-10', 'H1S1-09']
# 4532  ['H1S2-04', 'H1S2-04', 'H1S2-04']
# 4561  ['H1S2-03', 'H1S2-05', 'H1S1-02']
# 4598  ['H1S1-07', 'HSTA-02', 'H1S2-03']
# 4631  ['H1S2-03', 'H1S1-06', 'H1S1-08']
# 4644  ['H1S1-07', 'HSU1-07', 'H1S1-07']
# 4665  ['H1S1-07', 'H1S1-02', 'H1S1-05']
# 4686  ['H1S2-05', 'H1S1-10', 'H1S2-05']
# 4717  ['H1S2-01', 'H1S2-01', 'H1S2-01']
# 4721  ['H1S1-01', 'HSU1-03', 'H1S1-01']
# 4732  ['H1S1-02', 'HSTA-02', 'H1S1-03']
# 4742  ['H1S2-07', 'HSTA-02', 'H1S2-04']
# 4757  ['H1S2-07', 'HSTA-01', 'H1S2-07']
# 4796  ['H1S2-03', 'HSTA-04', 'H1S2-02']
# 4845  ['H1S2-05', 'H1S2-06', 'H1S2-06']
# 4920  ['H1S1-06', 'H1S1-08', 'HSU1-03']
# 4950  ['H1S2-05', 'H1S1-08', 'H1S1-08']
# 5008  ['H1S1-01', 'HSU1-03', 'H1S1-01']
# 5009  ['HSU1-04', 'HSU1-04', 'HSU1-04']
# 5055  ['H1S1-04', 'H1S1-03', 'HSTA-02']
# 5108  ['H1S2-01', 'H1S2-02', 'HSTA-01']
# 5111  ['HSU1-04', 'HSU1-04', 'HSU1-04']
# 5121  ['H1S1-01', 'HSU1-03', 'H1S2-05']
# 5138  ['HSU1-04', 'HSU1-04', 'HSU1-03']
# 5149  ['HSTA-01', 'H1S2-04', 'HSTA-03']
# 5214  ['HSU1-03', 'H1S2-05', 'H1S2-06']
# 5238  ['HSU1-05', 'H1S2-03', 'H1S2-01']
# 5262  ['H1S2-03', 'H1S2-03', 'HSU1-11']
# 5272  ['H1S1-08', 'H1S1-07', 'H1S1-05']
# 5285  ['H1S1-06', 'H1S1-11', 'H1S1-12']
# 5288  ['HSU1-01', 'HSU1-01', 'HSU1-10']
# 5358  ['H1S1-11', 'H1S1-06', 'H1S1-10']

# %%
from modules.preprocess_for_kobert import preprocess

df_train_label = preprocess(df_train_label)

# %%
df_train_label.loc[591, :]
# Out:
# chapter                  HSU1-02
# bert_80_pred_chapter     HSU1-02
# tfidf_pred_chapter       H1S1-01
# word2vec_pred_chapter    ['H1S2-05', 'H1S2-05', 'H1S2-04']
# text                     자연수 `N`에 대하여 `logN`의 정수부분을 `f(N)`이라고 할 때, `f(2)+f(4)+f(6)+...f(1004)`의 값을 구하시오.
# qtid                     HSU1-02-10
# name                     로그의 정수 부분과 소수 부분
# word2vec_pred_name       ['유리함수의 합성', '유리함수의 합성함수와 역함수', '합성함수와 역함수']
# qplay_question_id        8527
# token                    ['자연수', '`', 'N', '`', '대하', '`', 'logN', '`', '정수부분', '`', 'f', '(', 'N', ')', '`', '할', '때', ',', '`', 'f', '(', '2', ')', '+', 'f', '(', '4', ')', '+', 'f', '(', '6', ')', '+', '...', 'f', '(', '1004', ')', '`', '값', '구하시오', '.']
# math_field               ['N', 'logN', 'f(N)', 'f(2)+f(4)+f(6)+...f(1004)']
# hangul_field             ['자연수', '대하', '정수부분', '할', '때', '값', '구하시오']
# wrong_word2vec           1
# wrong_tfidf              1
# wrong_bert               0
# wrong_sum                2
# Name: 591, dtype: object

# %%
df_train_label.loc[635, :]
# Out:
# chapter                  HSU1-02
# bert_80_pred_chapter     HSU1-02
# tfidf_pred_chapter       H1S1-01
# word2vec_pred_chapter    ['HSU1-04', 'HSU1-04', 'HSU1-04']
# text                     `[log_(2)1]+[log_(2)2]+[log_(2)3]+…+[log_(2)256]`의 값을 구하여라. (단, `[x]`는 `x`를 넘지 않는 최대의 정수이다.)
# qtid                     HSU1-02-10
# name                     로그의 정수 부분과 소수 부분
# word2vec_pred_name       ['로그부등식 (5)', '로그방정식 (1)', '로그부등식 (1)']
# qplay_question_id        8735
# token                    ['`', '[', 'log', '_', '(', '2', ')', '1', ']', '+', '[', 'log', '_', '(', '2', ')', '2', ']', '+', '[', 'log', '_', '(', '2', ')', '3', ']', '+', 'cdots', '+', '[', 'log', '_', '(', '2', ')', '256', ']', '`', '값', '구하여', '.', '(', '단', ',', '`', '[', 'x', ']', '`', '`', 'x', '`', '넘', '않', '최대', '정수', '.', ')']
# math_field               ['[log_(2)1]+[log_(2)2]+[log_(2)3]+cdots+[log_(2)256]', '[x]', 'x']
# hangul_field             ['값', '구하여', '단', '넘', '않', '최대', '정수']
# wrong_word2vec           1
# wrong_tfidf              1
# wrong_bert               0
# wrong_sum                2
# Name: 635, dtype: object

# %%
df = pd.read_csv("data/몽데이크_Open.csv")
df = preprocess(df)

# %%
df.loc[635, :]
# Out:
# qplay_question_id           8735
# text                        `[log_(2)1]+[log_(2)2]+[log_(2)3]+…+[log_(2)256]`의 값을 구하여라. (단, `[x]`는 `x`를 넘지 않는 최대의 정수이다.)
# qtid                        HSU1-02-10
# name                        로그의 정수 부분과 소수 부분
# subtitle                    NaN
# question_difficulty         4
# question_type_difficulty    2
# grade                       10
# purpose                     open
# Name: 635, dtype: object

# %%
log 관련된 문제에서 

BERT 두 모델에서 토큰화된거 출력하는 방법 찾을 예정
word2vec과 tfidf 쪽 분석 계속 진행할까요
